# %% [markdown]
# # Laboratorio Del Sole
# ## Progetto artigianale di Noemi Fain

# %% [markdown]
# # Introduzione
# ## Da dove è nato?
# ### L'idea
# nel 2022, al ritorno da una vacanza
# ### Perché?
# - passare il tempo
# - incanalare lo stress
# - creare qualcosa di esteticamente piacevole
# ### L'obiettivo
# Gioielli originali e durevoli in un materiale tradizionale (ed economico)
#
# ## Domande
# - Come si distribuiscono le vendite rispetto le stagioni?
# - Il rapporto prezzo / ora è aumentato all'aumentare dell'esperienza?
# - Quale tipo di gioiello viene venduto più frequentemente?
# - Quanti di questi gioielli hanno un disegno originale?
# - Quali sono i tipi di gioiello più pesanti?

# %% [markdown]
# # I dati utilizzati
# ## Fonte
# - foto scattate
# - riepiloghi dei mercatini
# - misurazioni dirette
#
# ## Contenuto
# - caratteristiche dei gioielli
# - storico delle vendite (autunno 2023 - estate 2026)

# %% [markdown]
# # Come si distribuiscono le vendite rispetto le stagioni?

# %%
from IPython.display import Image
Image(filename = "Immagini/Passaparola-Mercatini.png")

# %% [markdown]
# # Il rapporto prezzo / ora è aumentato all'aumentare dell'esperienza?

# %%
Image(filename = "Immagini/Prezzo-Ora.png")

# %% [markdown]
# # Quale tipo di gioiello viene venduto più frequentemente?

# %%
Image(filename = "Immagini/Tipologie.png")

# %% [markdown]
# # Quanti di questi gioielli hanno un disegno originale?

# %%
Image(filename = "Immagini/Tipologia-design.png")

# %% [markdown]
# # Quali sono i tipi di gioiello più pesanti?
# Confronto: presenza di perline e origine del design

# %%
Image(filename = "Immagini/Peso.png")
